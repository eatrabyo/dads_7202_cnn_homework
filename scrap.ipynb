# %%
from bing_image_downloader import downloader
downloader.download('female elk with white spots', 
                    limit=500,
                    output_dir='dataset', 
                    adult_filter_off=True, 
                    force_replace=False, 
                    timeout=180, 
                    verbose=True)
# Out:
# [%] Downloading Images to d:\DADS\Semester03\DADS7202 Deep learning\dads_7202_cnn_homework\dataset\female elk with white spots
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.jendhamuni.com/wp-content/uploads/2015/07/Female-Elk.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.animalfactsencyclopedia.com/images/elk-female.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://1.bp.blogspot.com/_b_u832Cfidk/THAkKEkGAgI/AAAAAAAADFk/_wuAPQhtBno/s1600/female+elk2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.jamesmarvinphelps.com/img/s/v-10/p3119592914-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://lifeinmyyears.com/wp-content/uploads/2018/03/female-elk-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://images.fineartamerica.com/images/artworkimages/mediumlarge/1/female-elk-hughes-country-roads-photography.jpg
# ...
